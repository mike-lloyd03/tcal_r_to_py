# %%
dir_drive = 'c:'
dir_root = 'r_ri'
dir_subs = ['txt', 'ch', 'num', 'tr', 'chi' , 'numi']
dir_paths = [f'{dir_drive}/{dir_root}/{sub}' for sub in dir_subs]
dir_names = [f'{dir_root}.{sub}' for sub in dir_subs]
dir_names

# for i in range(1, len(dir_names)):
#   assign (dir_names[i], dir_paths[i])

# temp = paste(dir_drive, dir_root, sep='/')
# if( file.exists(temp)==F) dir.create(temp)
# rm(temp)
# for (i in 1:length(dir_paths) ) {
# assign( dir_names[i], dir_paths[i] )
# if( file.exists(dir_paths[i])==F) dir.create(dir_paths[[i]])
# }
# Out:
# ['r_ri.txt', 'r_ri.ch', 'r_ri.num', 'r_ri.tr', 'r_ri.chi', 'r_ri.numi']
